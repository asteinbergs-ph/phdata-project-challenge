# %% [markdown]
# ## KPI 1B
# #### Total number of flights by airport on a monthly basis

# %%
# Query the tables loaded from Snowflake for the data needed for this KPI, read results into a dataframe

sql_str = "SELECT \
  a.AIRPORT AS AIRPORT_NAME \
  ,a.IATA_CODE AS AIRPORT_CODE \
  ,c.MONTH \
  ,c.YEAR \
  ,c.FLIGHT_COUNT \
FROM user_andrew_db.AIRPORTS a \
LEFT JOIN ( \
  SELECT \
    AIRPORT \
    ,MONTH \
    ,YEAR \
    ,COUNT(1) AS FLIGHT_COUNT \
  FROM ( \
    SELECT \
      ORIGIN_AIRPORT AS AIRPORT \
      ,MONTH \
      ,YEAR \
    FROM user_andrew_db.FLIGHTS \
    UNION ALL \
    SELECT \
      DESTINATION_AIRPORT AS AIRPORT \
      ,MONTH \
      ,YEAR \
    FROM user_andrew_db.FLIGHTS \
  ) a \
  GROUP BY AIRPORT, MONTH, YEAR \
) c \
  ON a.IATA_CODE = c.AIRPORT \
ORDER BY a.AIRPORT, a.IATA_CODE, c.YEAR, c.MONTH"
 
df = sqlContext.sql(sql_str)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
airport_name = dbutils.widgets.get("Airports")

filtered_df = df.where(f"AIRPORT_NAME = \"{airport_name}\"")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##### **KPI 1B.1: Total number of flights by airport on a monthly basis**
# > ###### *Summary table (Databricks Visualizer)*

# %%
display(filtered_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AIRPORT_NAME</th><th>AIRPORT_CODE</th><th>MONTH</th><th>YEAR</th><th>FLIGHT_COUNT</th></tr></thead><tbody><tr><td>Baton Rouge Metropolitan Airport</td><td>BTR</td><td>1</td><td>2015</td><td>1311</td></tr><tr><td>Baton Rouge Metropolitan Airport</td><td>BTR</td><td>2</td><td>2015</td><td>1241</td></tr><tr><td>Baton Rouge Metropolitan Airport</td><td>BTR</td><td>3</td><td>2015</td><td>1409</td></tr><tr><td>Baton Rouge Metropolitan Airport</td><td>BTR</td><td>4</td><td>2015</td><td>1320</td></tr><tr><td>Baton Rouge Metropolitan Airport</td><td>BTR</td><td>5</td><td>2015</td><td>1338</td></tr><tr><td>Baton Rouge Metropolitan Airport</td><td>BTR</td><td>6</td><td>2015</td><td>1320</td></tr><tr><td>Baton Rouge Metropolitan Airport</td><td>BTR</td><td>7</td><td>2015</td><td>1350</td></tr><tr><td>Baton Rouge Metropolitan Airport</td><td>BTR</td><td>8</td><td>2015</td><td>1336</td></tr></tbody></table></div>

# %% [markdown]
# ##### **KPI 1B.2: Total number of flights by airport on a monthly basis**
# > ###### *Bar chart (Databricks Visualizer)*

# %%
display(filtered_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AIRPORT_NAME</th><th>AIRPORT_CODE</th><th>MONTH</th><th>YEAR</th><th>FLIGHT_COUNT</th></tr></thead><tbody><tr><td>Baton Rouge Metropolitan Airport</td><td>BTR</td><td>1</td><td>2015</td><td>1311</td></tr><tr><td>Baton Rouge Metropolitan Airport</td><td>BTR</td><td>2</td><td>2015</td><td>1241</td></tr><tr><td>Baton Rouge Metropolitan Airport</td><td>BTR</td><td>3</td><td>2015</td><td>1409</td></tr><tr><td>Baton Rouge Metropolitan Airport</td><td>BTR</td><td>4</td><td>2015</td><td>1320</td></tr><tr><td>Baton Rouge Metropolitan Airport</td><td>BTR</td><td>5</td><td>2015</td><td>1338</td></tr><tr><td>Baton Rouge Metropolitan Airport</td><td>BTR</td><td>6</td><td>2015</td><td>1320</td></tr><tr><td>Baton Rouge Metropolitan Airport</td><td>BTR</td><td>7</td><td>2015</td><td>1350</td></tr><tr><td>Baton Rouge Metropolitan Airport</td><td>BTR</td><td>8</td><td>2015</td><td>1336</td></tr></tbody></table></div>
