# %% [markdown]
# ## KPI 2
# #### On time percentage of each airline for the year 2015

# %%
# Query the tables loaded from Snowflake for the data needed for this KPI, read results into a dataframe

sql_str = "SELECT \
    a.AIRLINE AS AIRLINE_NAME \
    ,a.IATA_CODE AS AIRLINE_CODE \
    ,(1 - (b.DELAYED_FLIGHTS / b.FLIGHT_COUNT)) * 100 AS ON_TIME_PCT \
    ,(b.SEVERE_DELAY_FLIGHTS / b.FLIGHT_COUNT) * 100  AS SEVERE_DELAY_FLIGHT_PCT \
FROM user_andrew_db.AIRLINES a \
LEFT JOIN ( \
  SELECT \
    AIRLINE \
    ,YEAR \
    ,COUNT(1) AS FLIGHT_COUNT \
    ,SUM( \
        CASE WHEN DEPARTURE_DELAY > 0 OR ARRIVAL_DELAY > 0 THEN 1 ELSE 0 END \
    ) AS DELAYED_FLIGHTS \
    ,SUM( \
        CASE WHEN DEPARTURE_DELAY > 60 OR ARRIVAL_DELAY > 60 THEN 1 ELSE 0 END \
    ) AS SEVERE_DELAY_FLIGHTS \
  FROM user_andrew_db.FLIGHTS \
  WHERE YEAR = 2015 \
  GROUP BY AIRLINE, YEAR \
) b \
  ON a.IATA_CODE = b.AIRLINE \
ORDER BY a.AIRLINE, a.IATA_CODE, b.YEAR" \

df = sqlContext.sql(sql_str)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##### **KPI 2.1: On time percentage of each airline for the year 2015**
# > ###### *Summary table (Databricks Visualizer)*

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AIRLINE_NAME</th><th>AIRLINE_CODE</th><th>ON_TIME_PCT</th><th>SEVERE_DELAY_FLIGHT_PCT</th></tr></thead><tbody><tr><td>Alaska Airlines Inc.</td><td>AS</td><td>59.68415760916671</td><td>3.377710749388944</td></tr><tr><td>American Airlines Inc.</td><td>AA</td><td>52.71039959329884</td><td>7.0381894267114165</td></tr><tr><td>American Eagle Airlines Inc.</td><td>MQ</td><td>53.93004996431121</td><td>8.777064001903403</td></tr><tr><td>Atlantic Southeast Airlines</td><td>EV</td><td>55.26759908644421</td><td>7.593427249024799</td></tr><tr><td>Delta Air Lines Inc.</td><td>DL</td><td>56.98284417978166</td><td>5.088153549971899</td></tr><tr><td>Frontier Airlines Inc.</td><td>F9</td><td>44.0614455992811</td><td>10.970006273419353</td></tr><tr><td>Hawaiian Airlines Inc.</td><td>HA</td><td>54.81276166847573</td><td>1.6475422546131182</td></tr><tr><td>JetBlue Airways</td><td>B6</td><td>52.79556553905298</td><td>8.885685229266548</td></tr><tr><td>Skywest Airlines Inc.</td><td>OO</td><td>55.978017217495555</td><td>6.856522549478891</td></tr><tr><td>Southwest Airlines Co.</td><td>WN</td><td>46.943761809712335</td><td>6.366507212132901</td></tr><tr><td>Spirit Air Lines</td><td>NK</td><td>41.348117505367334</td><td>13.042624495994135</td></tr><tr><td>US Airways Inc.</td><td>US</td><td>53.53596859824372</td><td>5.093223963968498</td></tr><tr><td>United Air Lines Inc.</td><td>UA</td><td>39.86068586768666</td><td>9.376507847386105</td></tr><tr><td>Virgin America</td><td>VX</td><td>49.33435803356719</td><td>6.363884274983265</td></tr></tbody></table></div>

# %% [markdown]
# ##### **KPI 2.1: On time percentage of each airline for the year 2015**
# > ###### *Bar chart (Databricks Visualizer)*

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AIRLIN