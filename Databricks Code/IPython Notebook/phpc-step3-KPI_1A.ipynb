# %% [markdown]
# ## KPI 1A
# #### Total number of flights by airline on a monthly basis

# %%
# Query the tables loaded from Snowflake for the data needed for this KPI, read results into a dataframe

sql_str = "SELECT \
    a.AIRLINE AS AIRLINE_NAME \
    ,a.IATA_CODE AS AIRLINE_CODE \
    ,b.MONTH \
    ,b.YEAR \
    ,b.FLIGHT_COUNT \
FROM user_andrew_db.AIRLINES a \
LEFT JOIN ( \
  SELECT \
    AIRLINE \
    ,MONTH \
    ,YEAR \
    ,COUNT(1) AS FLIGHT_COUNT \
  FROM user_andrew_db.FLIGHTS \
  GROUP BY AIRLINE, MONTH, YEAR \
) b \
  ON a.IATA_CODE = b.AIRLINE \
ORDER BY a.AIRLINE, a.IATA_CODE, b.YEAR, b.MONTH"

df = sqlContext.sql(sql_str)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##### **KPI 1A.1: Total number of flights by airline on a monthly basis**
# > ###### *Summary table (Databricks Visualizer)*

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AIRLINE_NAME</th><th>AIRLINE_CODE</th><th>MONTH</th><th>YEAR</th><th>FLIGHT_COUNT</th></tr></thead><tbody><tr><td>Alaska Airlines Inc.</td><td>AS</td><td>1</td><td>2015</td><td>13257</td></tr><tr><td>Alaska Airlines Inc.</td><td>AS</td><td>2</td><td>2015</td><td>12194</td></tr><tr><td>Alaska Airlines Inc.</td><td>AS</td><td>3</td><td>2015</td><td>14276</td></tr><tr><td>Alaska Airlines Inc.</td><td>AS</td><td>4</td><td>2015</td><td>13974</td></tr><tr><td>Alaska Airlines Inc.</td><td>AS</td><td>5</td><td>2015</td><td>14682</td></tr><tr><td>Alaska Airlines Inc.</td><td>AS</td><td>6</td><td>2015</td><td>15075</td></tr><tr><td>Alaska Airlines Inc.</td><td>AS</td><td>7</td><td>2015</td><td>15821</td></tr><tr><td>Alaska Airlines Inc.</td><td>AS</td><td>8</td><td>2015</td><td>16095</td></tr><tr><td>American Airlines Inc.</td><td>AA</td><td>1</td><td>2015</td><td>44059</td></tr><tr><td>American Airlines Inc.</td><td>AA</td><td>2</td><td>2015</td><td>39835</td></tr><tr><td>American Airlines Inc.</td><td>AA</td><td>3</td><td>2015</td><td>45966</td></tr><tr><td>American Airlines Inc.</td><td>AA</td><td>4</td><td>2015</td><td>44770</td></tr><tr><td>American Airlines Inc.</td><td>AA</td><td>5</td><td>2015</td><td>44710</td></tr><tr><td>American Airlines Inc.</td><td>AA</td><td>6</td><td>2015</td><td>44360</td></tr><tr><td>American Airlines Inc.</td><td>AA</td><td>7</td><td>2015</td><td>81434</td></tr><tr><td>American Airlines Inc.</td><td>AA</td><td>8</td><td>2015</td><td>79748</td></tr><tr><td>American Eagle Airlines Inc.</td><td>MQ</td><td>1</td><td>2015</td><td>29900</td></tr><tr><td>American Eagle Airlines Inc.</td><td>MQ</td><td>2</td><td>2015</td><td>26940</td></tr><tr><td>American Eagle Airlines Inc.</td><td>MQ</td><td>3</td><td>2015</td><td>28146</td></tr><tr><td>American Eagle Airlines Inc.</td><td>MQ</td><td>4</td><td>2015</td><td>25695</td></tr><tr><td>American Eagle Airlines Inc.</td><td>MQ</td><td>5</td><td>2015</td><td>25431</td></tr><tr><td>American Eagle Airlines Inc.</td><td>MQ</td><td>6</td><td>2015</td><td>25407</td></tr><tr><td>American Eagle Airlines Inc.</td><td>MQ</td><td>7</td><td>2015</td><td>24750</td></tr><tr><td>American Eagle Airlines Inc.</td><td>MQ</td><td>8</td><td>2015</td><td>23881</td></tr><tr><td>Atlantic Southeast Airlines</td><td>EV</td><td>1</td><td>2015</td><td>49925</td></tr><tr><td>Atlantic Southeast Airlines</td><td>EV</td><td>2</td><td>2015</td><td>45138</td></tr><tr><td>Atlantic Southeast Airlines</td><td>EV</td><td>3</td><td>2015</td><td>54190</td></tr><tr><td>Atlantic Southeast Airlines</td><td>EV</td><td>4</td><td>2015</td><td>49296</td></tr><tr><td>Atlantic Southeast Airlines</td><td>EV</td><td>5</td><td>2015</td><td>49213</td></tr><tr><td>Atlantic Southeast Airlines</td><td>EV</td><td>6</td><td>2015</td><td>49119</td></tr><tr><td>Atlantic Southeast Airlines</td><td>EV</td><td>7</td><td>2015</td><td>50381</td></tr><tr><td>Atlantic Southeast Airlines</td><td>EV</td><td>8</td><td>2015</td><td>48554</td></tr><tr><td>Delta Air Lines Inc.</td><td>DL</td><td>1</td><td>2015</td><td>64421</td></tr><tr><td>Delta Air Lines Inc.</td><td>DL</td><td>2</td><td>2015</td><td>60884</td></tr><tr><td>Delta Air Lines Inc.</td><td>DL</td><td>3</td><td>2015</td><td>74166</td></tr><tr><td>Delta Air Lines Inc.</td><td>DL</td><td>4</td><td>2015</td><td>72170</td></tr><tr><td>Delta Air Lines Inc.</td><td>DL</td><td>5</td><td>2015</td><td>74815</td></tr><tr><td>Delta Air Lines Inc.</td><td>DL</td><td>6</td><td>2015</td><td>77255</td></tr><tr><td>Delta Air Lines Inc.</td><td>DL</td><td>7</td><td>2015</td><td>80741</td></tr><tr><td>Delta Air Lines Inc.</td><td>DL</td><td>8</td><td>2015</td><td>80947</td></tr><tr><td>Frontier Airlines Inc.</td><td>F9</td><td>1</td><td>2015</td><td>6829</td></tr><tr><td>Frontier Airlines Inc.</td><td>F9</td><td>2</td><td>2015</td><td>5809</td></tr><tr><td>Frontier Airlines ...

# %% [markdown]
# ##### **KPI 1A.2: Total number of flights by airline on a monthly basis**
# > ###### *Line chart (Databricks Visualizer)*

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AIRLINE_NAME</th><th>AIRLINE_CODE</th><th>MONTH</th><th>YEAR</th><th>FLIGHT_COUNT</th></tr></thead><tbody><tr><td>Alaska Airlines Inc.</td><td>AS</td><td>1</td><td>2015</td><td>13257</td></tr><tr><td>Alaska Airlines Inc.</td><td>AS</td><td>2</td><td>2015</td><td>12194</td></tr><tr><td>Alaska Airlines Inc.</td><td>AS</td><td>3</td><td>2015</td><td>14276</td></tr><tr><td>Alaska Airlines Inc.</td><td>AS</td><td>4</td><td>2015</td><td>13974</td></tr><tr><td>Alaska Airlines Inc.</td><td>AS</td><td>5</td><td>2015</td><td>14682</td></tr><tr><td>Alaska Airlines Inc.</td><td>AS</td><td>6</td><td>2015</td><td>15075</td></tr><tr><td>Alaska Airlines Inc.</td><td>AS</td><td>7</td><td>2015</td><td>15821</td></tr><tr><td>Alaska Airlines Inc.</td><td>AS</td><td>8</td><td>2015</td><td>16095</td></tr><tr><td>American Airlines Inc.</td><td>AA</td><td>1</td><td>2015</td><td>44059</td></tr><tr><td>American Airlines Inc.</td><td>AA</td><td>2</td><td>2015</td><td>39835</td></tr><tr><td>American Airlines Inc.</td><td>AA</td><td>3</td><td>2015</td><td>45966</td></tr><tr><td>American Airlines Inc.</td><td>AA</td><td>4</td><td>2015</td><td>44770</td></tr><tr><td>American Airlines Inc.</td><td>AA</td><td>5</td><td>2015</td><td>44710</td></tr><tr><td>American Airlines Inc.</td><td>AA</td><td>6</td><td>2015</td><td>44360</td></tr><tr><td>American Airlines Inc.</td><td>AA</td><td>7</td><td>2015</td><td>81434</td></tr><tr><td>American Airlines Inc.</td><td>AA</td><td>8</td><td>2015</td><td>79748</td></tr><tr><td>American Eagle Airlines Inc.</td><td>MQ</td><td>1</td><td>2015</td><td>29900</td></tr><tr><td>American Eagle Airlines Inc.</td><td>MQ</td><td>2</td><td>2015</td><td>26940</td></tr><tr><td>American Eagle Airlines Inc.</td><td>MQ</td><td>3</td><td>2015</td><td>28146</td></tr><tr><td>American Eagle Airlines Inc.</td><td>MQ</td><td>4</td><td>2015</td><td>25695</td></tr><tr><td>American Eagle Airlines Inc.</td><td>MQ</td><td>5</td><td>2015</td><td>25431</td></tr><tr><td>American Eagle Airlines Inc.</td><td>MQ</td><td>6</td><td>2015</td><td>25407</td></tr><tr><td>American Eagle Airlines Inc.</td><td>MQ</td><td>7</td><td>2015</td><td>24750</td></tr><tr><td>American Eagle Airlines Inc.</td><td>MQ</td><td>8</td><td>2015</td><td>23881</td></tr><tr><td>Atlantic Southeast Airlines</td><td>EV</td><td>1</td><td>2015</td><td>49925</td></tr><tr><td>Atlantic Southeast Airlines</td><td>EV</td><td>2</td><td>2015</td><td>45138</td></tr><tr><td>Atlantic Southeast Airlines</td><td>EV</td><td>3</td><td>2015</td><td>54190</td></tr><tr><td>Atlantic Southeast Airlines</td><td>EV</td><td>4</td><td>2015</td><td>49296</td></tr><tr><td>Atlantic Southeast Airlines</td><td>EV</td><td>5</td><td>2015</td><td>49213</td></tr><tr><td>Atlantic Southeast Airlines</td><td>EV</td><td>6</td><td>2015</td><td>49119</td></tr><tr><td>Atlantic Southeast Airlines</td><td>EV</td><td>7</td><td>2015</td><td>50381</td></tr><tr><td>Atlantic Southeast Airlines</td><td>EV</td><td>8</td><td>2015</td><td>48554</td></tr><tr><td>Delta Air Lines Inc.</td><td>DL</td><td>1</td><td>2015</td><td>64421</td></tr><tr><td>Delta Air Lines Inc.</td><td>DL</td><td>2</td><td>2015</td><td>60884</td></tr><tr><td>Delta Air Lines Inc.</td><td>DL</td><td>3</td><td>2015</td><td>74166</td></tr><tr><td>Delta Air Lines Inc.</td><td>DL</td><td>4</td><td>2015</td><td>72170</td></tr><tr><td>Delta Air Lines Inc.</td><td>DL</td><td>5</td><td>2015</td><td>74815</td></tr><tr><td>Delta Air Lines Inc.</td><td>DL</td><td>6</td><td>2015</td><td>77255</td></tr><tr><td>Delta Air Lines Inc.</td><td>DL</td><td>7</td><td>2015</td><td>80741</td></tr><tr><td>Delta Air Lines Inc.</td><td>DL</td><td>8</td><td>2015</td><td>80947</td></tr><tr><td>Frontier Airlines Inc.</td><td>F9</td><td>1</td><td>2015</td><td>6829</td></tr><tr><td>Frontier Airlines Inc.</td><td>F9</td><td>2</td><td>2015</td><td>5809</td></tr><tr><td>Frontier Airlines ...

# %% [markdown]
# ##### **KPI 1A.3: Total number of flights by airline on a monthly basis**
# > ###### *Per-airline bar chart (matplotlib)*

# %%
import random
from matplotlib import pyplot as plt
import calendar
import pyspark

# Convert to a Pandas dataframe to use additional functionality (apply, groupby)
if type(df) == pyspark.sql.dataframe.DataFrame:
  df = df.toPandas()
# Create a new appended column of month + year for more obvious display values
df['YEAR & MONTH'] = df.apply(lambda row: calendar.month_abbr[int(row.MONTH)] + ' ' + str(row.YEAR), axis = 1)

# Create a grouped dataframe, one dataframe for each airline, to show separate plots
grouped_df = df.groupby('AIRLINE_NAME')
# Dataframe length will be used to set figure size & number of subplots on figure
len_gdf = len(grouped_df)

# Plot each airline's data
# fig, axes = plt.subplots(int(len_gdf / 2), 2, figsize=(30,10*int(len_gdf / 2)))
fig, axes = plt.subplots(len_gdf, figsize=(15,10*len_gdf))
i_ax = 0
for key, grp in grouped_df:
  # Create a random color for each graph, scaled to 80% to make colors less intense
  rand_color = (random.random()*.8, random.random()*.8, random.random()*.8)
  axes[i_ax].bar(grp['YEAR & MONTH'], grp['FLIGHT_COUNT'], color=[rand_color], label=key)
  axes[i_ax].set_title(key, fontsize=20)
  axes[i_ax].set_xlabel("Year & Month", fontsize=14, labelpad=20.0)
  axes[i_ax].set_ylabel("Flights", fontsize=16, labelpad=20.0)
  i_ax += 1

# Set figure title, centered over plot
# Find mid point of left and right x-positions on subplot
mid = (fig.subplotpars.right + fig.subplotpars.left)/2
fig.suptitle("Total number of flights by airline on a monthly basis", x=mid, y=1, horizontalalignment='center', fontsize=26)
fig.tight_layout(pad=6.5)
plt.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [MONTH, YEAR] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# </div>
